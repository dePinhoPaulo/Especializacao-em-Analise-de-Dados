# %% [markdown]
# ### API IBGE
#
# https://servicodados.ibge.gov.br/api/docs

# %%
import requests
import pprint

link = "https://servicodados.ibge.gov.br/api/v3/agregados/7392/periodos/2014/variaveis/10484?localidades=N1[all]"

requisicao = requests.get(link)
informacoes = requisicao.json()

# pprint.pprint(informacoes)

item_busca = informacoes[0]['variavel']
resultados = informacoes[0]['resultados'][0]['series']

pprint.pprint(item_busca)
# Out:
# ('Número de espécies da fauna e da flora brasileira avaliadas quanto ao risco '
#  'de extinção')

# %%
print(item_busca)
print(resultados)
# Out:
# {'classificacoes': [{'id': '454', 'nome': 'Grupos taxonômicos, hábito ou forma de vida', 'categoria': {'47952': 'Total'}}, {'id': '919', 'nome': 'Tipo de ambiente', 'categoria': {'48243': 'Total'}}, {'id': '920', 'nome': 'Biomas, mar e ilhas oceânicas', 'categoria': {'48254': 'Total'}}, {'id': '12920', 'nome': 'Categorias de risco', 'categoria': {'119363': 'Total'}}], 'series': [{'localidade': {'id': '1', 'nivel': {'id': 'N1', 'nome': 'Brasil'}, 'nome': 'Brasil'}, 'serie': {'2014': '16645'}}]}
# [{'localidade': {'id': '1', 'nivel': {'id': 'N1', 'nome': 'Brasil'}, 'nome': 'Brasil'}, 'serie': {'2014': '16645'}}]
