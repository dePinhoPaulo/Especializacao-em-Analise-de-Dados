# %% [markdown]
# # Python e API com Login
#
# ### O 1º Passo de toda API com Login é criar uma conta e pegar suas credenciais
#
# ### No seu código, o 1º passo é sempre estabelecer a conexão com a API, usando seu login e suas credenciais
#
# - Como cada API é uma ferramenta diferente, cada uma delas pode exigir que você faça algum tipo de configuração, que vai estar explicada na API. No nosso caso, teremos que validar um número e criar um número de envio
#
# - Depois, usamos os métodos da API normalmente para fazer o que queremos. No nosso caso, enviar um SMS

# %% [markdown]
# #### 1. Vamos criar um login no Twilio
#
# https://www.twilio.com/docs/libraries/python

# %% [markdown]
# #### 2. Depois do Login, vamos pegar 3 informações:
#
# - ID da Conta
# - Token
# - Número de Envio

# %% [markdown]
# #### 3. Agora vamos validar um número porque no Twilio, enviar SMS para um número válido é de graça

# %% [markdown]
# #### 4. Agora podemos fazer o nosso código de acordo com as orientações do Twilio

# %%
# %pip install flask twilio
# Out:
# Collecting flask
#   Downloading flask-3.1.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting twilio
#   Downloading twilio-9.8.7-py2.py3-none-any.whl.metadata (13 kB)
# Collecting blinker>=1.9.0 (from flask)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting click>=8.1.3 (from flask)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting itsdangerous>=2.2.0 (from flask)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: jinja2>=3.1.2 in c:\users\kiko\appdata\local\programs\python\python312\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in c:\users\kiko\appdata\local\programs\python\python312\lib\site-packages (from flask) (3.0.3)
# Collecting werkzeug>=3.1.0 (from flask)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: requests>=2.0.0 in c:\users\kiko\appdata\local\programs\python\python312\lib\site-packages (from twilio) (2.32.5)
# Collecting PyJWT<3.0.0,>=2.0.0 (from twilio)
#   Using cached PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting aiohttp>=3.8.4 (from twilio)
#   Downloading aiohttp-3.13.2-cp312-cp312-win_amd64.whl.metadata (8.4 kB)
# Collecting aiohttp-retry>=2.8.3 (from twilio)
#   Downloading aiohttp_retry-2.9.1-py3-none-any.whl.metadata (8.8 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp>=3.8.4->twilio)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp>=3.8.4->twilio)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\kiko\appdata\local\programs\python\python312\lib\site-packages (from aiohttp>=3.8.4->twilio) (25.4.0)
# Collecting frozenlist>=1.1.1 (from aiohttp>=3.8.4->twilio)
#   Downloading frozenlist-1.8.0-cp312-cp312-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp>=3.8.4->twilio)
#   Downloading multidict-6.7.0-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp>=3.8.4->twilio)
#   Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp>=3.8.4->twilio)
#   Downloading yarl-1.22.0-cp312-cp312-win_amd64.whl.metadata (77 kB)
# Requirement already satisfied: idna>=2.0 in c:\users\kiko\appdata\local\programs\python\python312\lib\site-packages (from yarl<2.0,>=1.17.0->aiohttp>=3.8.4->twilio) (3.10)
# Requirement already satisfied: typing-extensions>=4.2 in c:\users\kiko\appdata\local\programs\python\python312\lib\site-packages (from aiosignal>=1.4.0->aiohttp>=3.8.4->twilio) (4.15.0)
# Requirement already satisfied: colorama in c:\users\kiko\appdata\roaming\python\python312\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\kiko\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->twilio) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\kiko\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->twilio) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\kiko\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->twilio) (2025.10.5)
# Downloading flask-3.1.2-py3-none-any.whl (103 kB)
# Downloading twilio-9.8.7-py2.py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------- ----------------- 1.0/1.8 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 7.8 MB/s  0:00:00
# Using cached PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Downloading aiohttp-3.13.2-cp312-cp312-win_amd64.whl (453 kB)
# Downloading multidict-6.7.0-cp312-cp312-win_amd64.whl (46 kB)
# Downloading yarl-1.22.0-cp312-cp312-win_amd64.whl (87 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiohttp_retry-2.9.1-py3-none-any.whl (10.0 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Downloading frozenlist-1.8.0-cp312-cp312-win_amd64.whl (44 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading propcache-0.4.1-cp312-cp312-win_amd64.whl (41 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Installing collected packages: werkzeug, PyJWT, propcache, multidict, itsdangerous, frozenlist, click, blinker, aiohappyeyeballs, yarl, flask, aiosignal, aiohttp, aiohttp-retry, twilio
#
#    ----------------------------------------  0/15 [werkzeug]
#    ----------------------------------------  0/15 [werkzeug]
#    ----------------------------------------  0/15 [werkzeug]
#    ----------------------------------------  0/15 [werkzeug]
#    ----------------------------------------  0/15 [werkzeug]
#    -- -------------------------------------  1/15 [PyJWT]
#    -------- -------------------------------  3/15 [multidict]
#    ------------- --------------------------  5/15 [frozenlist]
#    ---------------- -----------------------  6/15 [click]
#    ------------------ ---------------------  7/15 [blinker]
#    ------------------------ ---------------  9/15 [yarl]
#    -------------------------- ------------- 10/15 [flask]
#    -------------------------- ------------- 10/15 [flask]
#    -------------------------- ------------- 10/15 [flask]
#    -------------------------------- ------- 12/15 [aiohttp]
#    -------------------------------- ------- 12/15 [aiohttp]
#    -------------------------------- ------- 12/15 [aiohttp]
#    -------------------------------- ------- 12/15 [aiohttp]
#    -------------------------------- ------- 12/15 [aiohttp]
#    -------------------------------- ------- 12/15 [aiohttp]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ------------------------------------- -- 14/15 [twilio]
#    ---------------------------------------- 15/15 [twilio]
#
# Successfully installed PyJWT-2.10.1 aiohappyeyeballs-2.6.1 aiohttp-3.13.2 aiohttp-retry-2.9.1 aiosignal-1.4.0 blinker-1.9.0 click-8.3.1 flask-3.1.2 frozenlist-1.8.0 itsdangerous-2.2.0 multidict-6.7.0 propcache-0.4.1 twilio-9.8.7 werkzeug-3.1.3 yarl-1.22.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Download the helper library from https://www.twilio.com/docs/python/install
import os
from twilio.rest import Client

# Find your Account SID and Auth Token at twilio.com/console
# and set the environment variables. See http://twil.io/secure
account_sid = 'xxx'
auth_token = 'xxx'
client = Client(account_sid, auth_token)

message = client.messages.create(
    body='Hello World',
    from_='+xxx',
    to='+xxx',
)

print(message.body)
# Out:
# ---------------------------------------------------------------------------
# TwilioRestException                       Traceback (most recent call last)
# Cell In[12], line 11
#       8 auth_token = 'xxx'
#       9 client = Client(account_sid, auth_token)
# ---> 11 message = client.messages.create(
#      12     body='Hello World',
#      13     from_='+xxx',
#      14     to='+xxx',
#      15 )
#      17 print(message.body)
#
# File c:\Users\Kiko\AppData\Local\Programs\Python\Python312\Lib\site-packages\twilio\rest\api\v2010\account\message\__init__.py:589, in MessageList.create(self, to, status_callback, application_sid, max_price, provide_feedback, attempt, validity_period, force_delivery, content_retention, address_retention, smart_encoded, persistent_action, traffic_type, shorten_urls, schedule_type, send_at, send_as_mms, content_variables, risk_check, from_, messaging_service_sid, body, media_url, content_sid)
#     585 headers["Content-Type"] = "application/x-www-form-urlencoded"
#     587 headers["Accept"] = "application/json"
# --> 589 payload = self._version.create(
#     590     method="POST", uri=self._uri, data=data, headers=headers
#     591 )
#     593 return MessageInstance(
#     594     self._version, payload, account_sid=self._solution["account_sid"]
#     595 )
#
# File c:\Users\Kiko\AppData\Local\Programs\Python\Python312\Lib\site-packages\twilio\base\version.py:463, in Version.create(self, method, uri, params, data, headers, auth, timeout, allow_redirects)
#     450 """
#     451 Create a resource instance.
#     452 """
#     453 response = self.request(
#     454     method,
#     455     uri,
#    (...)    461     allow_redirects=allow_redirects,
#     462 )
# --> 463 return self._parse_create(method, uri, response)
#
# File c:\Users\Kiko\AppData\Local\Programs\Python\Python312\Lib\site-packages\twilio\base\version.py:435, in Version._parse_create(self, method, uri, response)
#     431 """
#     432 Parse create response JSON
#     433 """
#     434 if response.status_code < 200 or response.status_code >= 300:
# --> 435     raise self.exception(method, uri, response, "Unable to create record")
#     437 return json.loads(response.text)
#
# TwilioRestException: HTTP 401 error: Unable to create record: Authentication Error - invalid username
