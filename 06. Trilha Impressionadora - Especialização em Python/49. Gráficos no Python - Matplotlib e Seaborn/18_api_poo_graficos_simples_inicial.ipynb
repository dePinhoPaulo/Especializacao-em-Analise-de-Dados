# %% [markdown]
# # Trabalhando com eixos

# %% [markdown]
# ## Gráfico de linhas

# %%
import matplotlib.pyplot as plt

meses = ['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez']
vendas = [85, 90, 78, 92, 88, 96, 94, 98, 100, 102, 105, 108]

fig, ax = plt.subplots()

ax.plot(meses, vendas)
ax.set_xlabel('Meses')
ax.set_ylabel('Vendas (Milhares de Reias)')
ax.set_title('Evolução de Vendas')

plt.show()

# %% [markdown]
# ## Gráfico de barras

# %%
import matplotlib.pyplot as plt

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

fig, ax = plt.subplots()
ax.set_xlabel('Produtos')
ax.set_ylabel('Quantidade de Vendas')
ax.set_title('Vendas por Produtos')

ax.bar(produtos, quantidades)

plt.show()

# %% [markdown]
# ## Gráfico de pizza

# %%
categorias = ['Eletrônicos', 'Roupas', 'Alimentos', 'Livros']
quantidades = [45, 30, 15, 10]
destaque = [0.1, 0, 0, 0]  # destacar a primeira fatia

fig, ax = plt.subplots()

ax.pie(quantidades, labels=categorias, explode=destaque, autopct='%1.f')

plt.show()

# %% [markdown]
# ## Gráfico de barras empilhadas

# %%
anos = [2018, 2019, 2020, 2021]
vendas_online = [5, 10, 15, 20]
vendas_loja = [10, 8, 6, 4]

fig, ax = plt.subplots()

ax.bar(anos, vendas_online, label='Online')
ax.bar(anos, vendas_loja, bottom=vendas_online, label='Loja')

ax.legend()

ax.set_xlabel('Anos')
ax.set_ylabel('Vendas em Milhões')
ax.set_title('Vendas Online Vs Loja')

ax.set_xticks(anos)

plt.show()
