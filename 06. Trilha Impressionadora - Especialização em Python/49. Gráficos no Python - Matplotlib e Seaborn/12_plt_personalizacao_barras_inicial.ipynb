# %% [markdown]
# # Mais personalizações possíveis

# %% [markdown]
# ## Gráfico de barras para apresentação
#
# Considere que você tem as quantidades de produtos vendidos em uma loja. Faça um gráfico de barras horizontais.

# %%
import matplotlib.pyplot as plt

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

plt.bar(produtos, quantidades)
plt.show()
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#barras horizontais
import matplotlib.pyplot as plt

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh(produtos, quantidades)

plt.bar_label(barras, labels=quantidades, fontsize=10, fontweight='bold', padding=3)

plt.box(False)
plt.xticks([])
plt.tick_params(axis='y', length=0)

plt.title('Qantidade de Produtos Vendidos')

plt.show()

# %%
#barras horizontais
import matplotlib.pyplot as plt
from cycler import cycler

cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)

produtos = ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
quantidades = [23, 45, 17, 30, 37]

barras = plt.barh(produtos, quantidades)

for i, barra in enumerate(barras):
    if i != quantidades.index(max(quantidades)):
        barras[i].set_color(cores[1])
        barras[i].set_alpha(0.5)

plt.bar_label(barras, labels=quantidades, fontsize=10, fontweight='bold', padding=3)

plt.box(False)
plt.xticks([])
plt.tick_params(axis='y', length=0)

plt.title('Qantidade de Produtos Vendidos')

plt.show()

# %%
print(produtos)
print(quantidades)

print(zip(quantidades, produtos)) #Compacta as duas listas em tupla
print(list(zip(quantidades, produtos))) #passa para uma lista
print(sorted(list(zip(quantidades, produtos)))) #ordena as tuplas
print(type(sorted(list(zip(quantidades, produtos)))))
# Out:
# ['Produto A', 'Produto B', 'Produto C', 'Produto D', 'Produto E']
# [23, 45, 17, 30, 37]
# ...
# [(23, 'Produto A'), (45, 'Produto B'), (17, 'Produto C'), (30, 'Produto D'), (37, 'Produto E')]
# [(17, 'Produto C'), (23, 'Produto A'), (30, 'Produto D'), (37, 'Produto E'), (45, 'Produto B')]
# <class 'list'>

# %%
dados_ordenado = sorted(list(zip(quantidades, produtos)))
print(dados_ordenado)

quantidades_ordenado = [dado[0] for dado in dados_ordenado]
print(quantidades_ordenado)
produtos_ordenado = [dado[1] for dado in dados_ordenado]
print(produtos_ordenado)
# Out:
# [(17, 'Produto C'), (23, 'Produto A'), (30, 'Produto D'), (37, 'Produto E'), (45, 'Produto B')]
# [17, 23, 30, 37, 45]
# ['Produto C', 'Produto A', 'Produto D', 'Produto E', 'Produto B']

# %%
#barras horizontais pt2
import matplotlib.pyplot as plt
from cycler import cycler

cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)

barras = plt.barh(produtos_ordenado, quantidades_ordenado)

for i, barra in enumerate(barras):
    if i != quantidades_ordenado.index(max(quantidades_ordenado)):
        barras[i].set_color(cores[1])
        barras[i].set_alpha(0.5)

plt.bar_label(barras, labels=quantidades, fontsize=10, fontweight='bold', padding=3)

plt.box(False)
plt.xticks([])
plt.tick_params(axis='y', length=0)

plt.title('Qantidade de Produtos Vendidos')

plt.show()

# %%
#barras horizontais pt2
import matplotlib.pyplot as plt
from cycler import cycler

cores = plt.get_cmap('Pastel2').colors
ciclo_cores = cycler('color', cores)
plt.rc('axes', prop_cycle=ciclo_cores)

barras = plt.barh(produtos_ordenado, quantidades_ordenado)

for i, barra in enumerate(barras):
    if i != quantidades_ordenado.index(max(quantidades_ordenado)):
        barras[i].set_color(cores[1])
        barras[i].set_alpha(0.5)

plt.bar_label(barras, labels=quantidades, fontsize=10, fontweight='bold', padding=3)

plt.box(False)
plt.xticks([])
plt.tick_params(axis='y', length=0)

plt.title('Qantidade de Produtos Vendidos')

plt.gca().invert_yaxis()

plt.show()
