# %% [markdown]
# ### Automatizar Emissão de Nota Fiscal

# %%
# Entrar na pagina de login
# Preencher login e senha
# Clicar no botão de fazer login
# Preencher dados da NF
# Clicar em emitir nota fiscal

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

options = webdriver.ChromeOptions()
options.add_experimental_option("prefs", {
  "download.default_directory": r'C:\Users\Kiko\Downloads',
  "download.prompt_for_download": False,
  "download.directory_upgrade": True,
  "safebrowsing.enabled": True
})

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(options=options)

# %%
navegador.get(r"C:\Users\Kiko\Documents\Projetos Programação\Especializacao-em-Analise-de-Dados\06. Trilha Impressionadora - Especialização em Python\50. Integração Python - Automação Web (Web-Scraping com Selenium)\Exercício - Automatizar Emissão de Nota Fiscal\login.html")

# %%
#Fazer login no sistema

#Inserir Login
navegador.find_element(By.XPATH, '/html/body/div/form/input[1]').send_keys('Paulo.Pinho')

#Inserir Senha
navegador.find_element(By.XPATH, '/html/body/div/form/input[2]').send_keys('Paulo@1234')

#Clicar em Login
navegador.find_element(By.XPATH, '/html/body/div/form/button').click()

# %%
#Destinatário da mercadoria e/ou tomador do serviço

navegador.find_element(By.NAME, 'nome').send_keys('Paulo Pinho')

navegador.find_element(By.NAME, 'endereco').send_keys('Rua japão')

navegador.find_element(By.NAME, 'bairro').send_keys('Centro')

navegador.find_element(By.NAME, 'municipio').send_keys('Londrina')

navegador.find_element(By.NAME, 'cep').send_keys('86270000')

navegador.find_element(By.NAME, 'uf').send_keys('PR')

navegador.find_element(By.NAME, 'cnpj').send_keys(99999999999)

navegador.find_element(By.NAME, 'inscricao').send_keys(99999999999)

# %%
#Descrição das mercadorias/serviço prestado

navegador.find_element(By.NAME, 'descricao').send_keys('Mouse')

navegador.find_element(By.NAME, 'quantidade').send_keys(1)

navegador.find_element(By.NAME, 'valor_unitario').send_keys(129.90)

navegador.find_element(By.NAME, 'total').send_keys(129.90)

# %%
#Clicar em Emitir nota
navegador.find_element(By.CLASS_NAME, 'registerbtn').click()
