# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

# %%
navegador.get(r"C:\Users\Kiko\Documents\Projetos Programação\Especializacao-em-Analise-de-Dados\06. Trilha Impressionadora - Especialização em Python\50. Integração Python - Automação Web (Web-Scraping com Selenium)\Arquivos\teste.html")

# %% [markdown]
# ##Aula 4

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

# %%
navegador.get(r"C:\Users\Kiko\Downloads\Métodos de Seleção do Selenium\Arquivos\Pagina Hashtag.html")

# %%
from selenium.webdriver.common.by import By

navegador.find_element(By.ID, 'fullname').send_keys('Paulo')
navegador.find_element(By.ID, 'email').send_keys('paulo.pinho@gmail.com')
navegador.find_element(By.ID, '_form_176_submit').click()
