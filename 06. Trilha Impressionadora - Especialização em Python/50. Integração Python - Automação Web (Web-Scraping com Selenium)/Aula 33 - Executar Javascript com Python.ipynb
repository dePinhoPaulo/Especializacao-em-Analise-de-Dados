# %% [markdown]
# ### Executar Comandos Javascript (Scroll da tela)
#
# - Você consegue, por meio do Selenium, executar comandos javascript no seu navegador
#
# - Isso é essencial para dar scroll na tela, por exemplo, caso seja necessário, como no youtube

# %%
# quero pegar uma lista de pelo menos 50 vídeos de Python do Youtube

# window.scroll(0, 100)
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

# %%
navegador.get("https://www.youtube.com/results?search_query=python")

# %%
# vou dar scroll na tela
for i in range(30):
    qtd_scroll = i * 1000
    navegador.execute_script(f'window.scroll(0, {qtd_scroll})')

lista_video = navegador.find_elements(By.ID, 'thumbnail')
print(len(lista_video))

for video in lista_video:
    print(video.get_attribute('href'))
# Out:
# 320
# https://www.youtube.com/watch?v=XZsrb8IFoyM
# https://www.youtube.com/watch?v=-VeVq64Fgw0&pp=ygUGcHl0aG9u0gcJCQgKAYcqIYzv
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=ix9cRaBkVe0&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=4d5C_PQl8Tg&list=RD4d5C_PQl8Tg&start_radio=1&pp=ygUGcHl0aG9uoAcB
# https://www.youtube.com/watch?v=_uQrJ0TkZlc&pp=ygUGcHl0aG9u0gcJCQgKAYcqIYzv
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=K5KVEU3aaeQ&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=wUSDVGivd-8&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=2uBrqwj70TQ&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=4p7axLXXBGU&pp=ygUGcHl0aG9u0gcJCQgKAYcqIYzv
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=3J1xBL7zJXg&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=GfH4QL4VqJ0&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=OEJv74QnduA&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=gaGaPpnexxA&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=Ex1zE8OUdC8&pp=ygUGcHl0aG9u0gcJCQgKAYcqIYzv
# None
# None
# None
# None
# https://www.youtube.com/watch?v=Pss9bjQYToM&list=RDPss9bjQYToM&start_radio=1&pp=ygUGcHl0aG9uoAcB
# https://www.youtube.com/watch?v=BxMtSb2w9Sk&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=nLRL_NcnK-4&pp=ygUGcHl0aG9u
# https://www.youtube.com/watch?v=5NgNicANyqM&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=nODe5lFcGpg&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=crTjJFOxE40&pp=ygUGcHl0aG9u0gcJCQgKAYcqIYzv
# https://www.youtube.com/watch?v=OFLMhFuArXQ&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=ygXn5nV5qFc&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=Gx5qb1uHss4&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=t8pPdKYpowI&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=x7X9w_GIm1s&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=8DvywoWv6fI&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=XZsrb8IFoyM
# https://www.youtube.com/watch?v=mRMmlo_Uqcs&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=Ro_MScTDfU4&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=NRFZFXT1JvM&pp=ygUGcHl0aG9u0gcJCQgKAYcqIYzv
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=FRmEvZFEbaQ&pp=ygUGcHl0aG9u0gcJCQgKAYcqIYzv
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=kqtD5dpn9C8&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=rfscVS0vtbw&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=mB0EBW-vDSQ&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=0K_eZGS5NsU&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=Pss9bjQYToM&list=RDPss9bjQYToM&start_radio=1&pp=ygUGcHl0aG9uoAcB
# https://www.youtube.com/watch?v=fWjsdhR3z3c&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=t8pPdKYpowI&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=qwAFL1597eM&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=nLRL_NcnK-4&pp=ygUGcHl0aG9u
# https://www.youtube.com/watch?v=KW6qncswzHw&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=RO5ymA6wGKk&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# https://www.youtube.com/watch?v=b093aqAZiPU&pp=ygUGcHl0aG9u
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
