# %% [markdown]
# ### Documentacao Selenium:
#
# - https://selenium-python.readthedocs.io/locating-elements.html

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

servico = Service(ChromeDriverManager().install())
navegador = webdriver.Chrome(service=servico)

# %%
navegador.get(r"C:\Users\Kiko\Documents\Projetos Programação\Especializacao-em-Analise-de-Dados\06. Trilha Impressionadora - Especialização em Python\50. Integração Python - Automação Web (Web-Scraping com Selenium)\Arquivos\formulario.html")

# %% [markdown]
# #### Botao Padrao (clicar em botao)

# %%
navegador.find_element(By.XPATH, '/html/body/form/input[1]').click()

alerta = navegador.switch_to.alert
alerta.accept()

# %% [markdown]
# #### Dica, esteja atento ao atributo "value" dos inputs, ele pode te ajudar
#
# - .text
# - .get_attribute("value")
# - .is_selected

# %% [markdown]
# #### Botao de Selecao estilo Checkbox (clicar no botao)

# %%
# clicar no botao
navegador.find_element(By.XPATH, '/html/body/form/input[3]').click()

# %%
# verificar o valor do botao
navegador.find_element(By.XPATH, '/html/body/form/input[3]').is_selected()
# Out:
# False

# %% [markdown]
# #### Botao de Selecao de Cores (enviar valor)

# %%
# preencher a cor
navegador.find_element(By.XPATH, '/html/body/form/input[4]').send_keys('#aa1d1d')

# %%
# verificar qual a cor foi selecionada
valor_cor = navegador.find_element(By.XPATH, '/html/body/form/input[4]').get_attribute('value')
print(valor_cor)
# Out:
# #aa1d1d

# %% [markdown]
# #### Botao de Datas (enviar valor)

# %%
# preencher o valor
navegador.find_element(By.XPATH, '/html/body/form/input[6]').send_keys('10/23/2001')

# %%
# pegar o valor
valor_data = navegador.find_element(By.XPATH, '/html/body/form/input[6]').get_attribute('value')
print(valor_data)
# Out:
# 2001-10-23

# %% [markdown]
# #### Botao de Datas com Horas (enviar valor)

# %%
# preenchendo
navegador.find_element(By.XPATH, '/html/body/form/input[7]').send_keys('10/23/2001\t12:30\tAM')

from selenium.webdriver.common.keys import Keys
navegador.find_element(By.XPATH, '/html/body/form/input[7]').send_keys('10/30/2001', Keys.TAB, '05:00', Keys.TAB, 'PM')

# %%
# pegando o valor
valor_data_hora = navegador.find_element(By.XPATH, '/html/body/form/input[7]').get_attribute('value')
print(valor_data_hora)
# Out:
# 2001-10-30T17:00

# %% [markdown]
# #### Botao para selecionar o arquivo (enviar valor com caminho completo)

# %%
# preenchendo
navegador.find_element(By.XPATH, '/html/body/form/input[8]').send_keys(r'C:\Users\Kiko\Downloads\Pagina Hashtag.html')

# %%
# pegar o valor
valor_anexo = navegador.find_element(By.XPATH, '/html/body/form/input[8]').get_attribute('value')
print(valor_anexo)
# Out:
# C:\fakepath\formulario.html

# %% [markdown]
# #### Botao para selecionar mes e ano (enviar valor)

# %%
# preenche
navegador.find_element(By.XPATH, '/html/body/form/input[9]').send_keys('novembro\t2001')

# pegar o valor
valor_mes_ano = navegador.find_element(By.XPATH, '/html/body/form/input[9]').get_attribute('value')
print(valor_mes_ano)
# Out:
# 2001-11

# %% [markdown]
# #### Campos Numericos

# %%
# preenche
navegador.find_element(By.XPATH, '/html/body/form/input[10]').clear()
navegador.find_element(By.XPATH, '/html/body/form/input[10]').send_keys(2001)

# pegar o valor
valor_numerico = navegador.find_element(By.XPATH, '/html/body/form/input[10]').get_attribute('value')
print(valor_numerico)
# Out:
# 2001

# %% [markdown]
# #### Campos de Senha

# %%
# preenche
navegador.find_element(By.XPATH, '/html/body/form/input[11]').clear()
navegador.find_element(By.XPATH, '/html/body/form/input[11]').send_keys(2025)

# pegar o valor
valor_senha = navegador.find_element(By.XPATH, '/html/body/form/input[11]').get_attribute('value')
print(valor_senha)
# Out:
# 2025

# %% [markdown]
# #### RadioButtons (botoes que so consegue marcar 1)

# %%
# preenche
navegador.find_element(By.XPATH, '/html/body/form/input[13]').click()

# %%
# pegar o valor
valor_radio_button = navegador.find_element(By.XPATH, '/html/body/form/input[13]').is_selected()
print(valor_radio_button)
# Out:
# True

# %% [markdown]
# #### Slider (enviar valor)

# %%
# pegar o valor
valor_slider = navegador.find_element(By.XPATH, '/html/body/form/input[15]').get_attribute('value')
print(valor_slider)
# Out:
# 71

# %%
# preencher o valor
elemento_slider = navegador.find_element(By.XPATH, '/html/body/form/input[15]')
elemento_slider.clear()
for i in range(100 - 50):
    elemento_slider.send_keys(Keys.ARROW_RIGHT)

# %% [markdown]
# #### Caixa de Texto

# %%
# preencher
navegador.find_element(By.XPATH, '/html/body/form/input[16]').send_keys('Flamengo')

# %%
valor_time = navegador.find_element(By.XPATH, '/html/body/form/input[16]').get_attribute('value')
print(valor_time)
# Out:
# Flamengo

# %% [markdown]
# #### Caixa de Horas

# %%
# preencher
navegador.find_element(By.XPATH, '/html/body/form/input[17]').send_keys('18:15')

# pegar o valor
valor_horas = navegador.find_element(By.XPATH, '/html/body/form/input[17]').get_attribute('value')
print(valor_horas)
# Out:
# 18:15

# %% [markdown]
# #### Caixa de Data Personalizada (Semanal)

# %%
# preencher
navegador.find_element(By.XPATH, '/html/body/form/input[18]').send_keys('50\t2025')

# pegar o valor
valor_semana = navegador.find_element(By.XPATH, '/html/body/form/input[18]').get_attribute('value')
print(valor_semana)
# Out:
# 2025-W50

# %% [markdown]
# #### Blocos de texto (enviar valor)

# %%
# preencher
navegador.find_element(By.XPATH, '//*[@id="story"]').send_keys('Ola\nMeu nome é Paulo\n24 anos')

# pegar o valor
valor_texto = navegador.find_element(By.XPATH, '//*[@id="story"]').get_attribute('value')
print(valor_texto)
# Out:
# Ola
# Meu nome é Paulo
# 24 anos

# %% [markdown]
# #### Selecionando itens de uma lista

# %%
# preencher o valor
navegador.find_element(By.XPATH, '/html/body/form/select[1]').send_keys('b')

# %%
# pegando o valor
valor_lista = navegador.find_element(By.XPATH, '/html/body/form/select[1]').get_attribute('value')
print(valor_lista)
# Out:
# b

# %%
# clicando para selecionar
import time

navegador.find_element(By.XPATH, '/html/body/form/select[1]').click()
time.sleep(0.5)
navegador.find_element(By.XPATH, '/html/body/form/select[1]/option[2]').click()

# %%
# com o select
# https://www.selenium.dev/pt-br/documentation/webdriver/elements/select_lists/

from selenium.webdriver.support.select import Select

elemento = navegador.find_element(By.TAG_NAME, 'select')
elemento_select = Select(elemento)

elemento_select.select_by_visible_text('C')

# %%
# pengado valor com select

item = elemento_select.first_selected_option
print(item.get_attribute('value'))

lista_item = elemento_select.all_selected_options
print(lista_item[0].get_attribute('value'))
# Out:
# c
# c

# %%
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="6c558e556921e135c0548455ed72e91d", element="e7fd38b5-e430-4bca-9935-943cde605748")>]
# b
